# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

import warnings
warnings.filterwarnings('ignore')

# para pintar
import pylab as plt
import seaborn as sns

# para que salga el grafico
# %matplotlib inline

# %%
actor = pd.read_csv('../data/actor.csv', encoding = "ISO-8859-1")
category = pd.read_csv('../data/category.csv', encoding = "ISO-8859-1")
film = pd.read_csv('../data/film.csv', encoding = "ISO-8859-1")
inventory = pd.read_csv('../data/inventory.csv', encoding = "ISO-8859-1")
language = pd.read_csv('../data/language.csv', encoding = "ISO-8859-1")
old_HDD = pd.read_csv('../data/old_HDD.csv', encoding = "ISO-8859-1")
rental = pd.read_csv('../data/rental.csv', encoding = "ISO-8859-1")

# %%
actor.head(20)
# Out:
#     actor_id first_name     last_name          last_update
# 0          1   PENELOPE       GUINESS  2006-02-15 04:34:33
# 1          2       NICK      WAHLBERG  2006-02-15 04:34:33
# 2          3         ED         CHASE  2006-02-15 04:34:33
# 3          4   JENNIFER         DAVIS  2006-02-15 04:34:33
# 4          5     JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33
# 5          6      BETTE     NICHOLSON  2006-02-15 04:34:33
# 6          7      GRACE        MOSTEL  2006-02-15 04:34:33
# 7          8    MATTHEW     JOHANSSON  2006-02-15 04:34:33
# 8          9        JOE         SWANK  2006-02-15 04:34:33
# 9         10  CHRISTIAN         GABLE  2006-02-15 04:34:33
# 10        11       ZERO          CAGE  2006-02-15 04:34:33
# 11        12       KARL         BERRY  2006-02-15 04:34:33
# 12        13        UMA          WOOD  2006-02-15 04:34:33
# 13        14     VIVIEN        BERGEN  2006-02-15 04:34:33
# 14        15       CUBA       OLIVIER  2006-02-15 04:34:33
# ...

# %%
actor.shape
# Out:
# (200, 4)

# %%
actor.columns
# Out:
# Index(['actor_id', 'first_name', 'last_name', 'last_update'], dtype='object')

# %%
actor.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   actor_id     200 non-null    int64
#  1   first_name   200 non-null    object
#  2   last_name    200 non-null    object
#  3   last_update  200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 41.0 KB

# %%
actor.describe(include='all').T
# Out:
#              count unique                  top freq   mean        std  min  \
# actor_id     200.0    NaN                  NaN  NaN  100.5  57.879185  1.0
# first_name     200    128             PENELOPE    4    NaN        NaN  NaN
# last_name      200    121               KILMER    5    NaN        NaN  NaN
# last_update    200      1  2006-02-15 04:34:33  200    NaN        NaN  NaN
#
#                25%    50%     75%    max
# actor_id     50.75  100.5  150.25  200.0
# first_name     NaN    NaN     NaN    NaN
# last_name      NaN    NaN     NaN    NaN
# last_update    NaN    NaN     NaN    NaN

# %%
actor.tail()
# Out:
#      actor_id first_name last_name          last_update
# 195       196       BELA    WALKEN  2006-02-15 04:34:33
# 196       197      REESE      WEST  2006-02-15 04:34:33
# 197       198       MARY    KEITEL  2006-02-15 04:34:33
# 198       199      JULIA   FAWCETT  2006-02-15 04:34:33
# 199       200      THORA    TEMPLE  2006-02-15 04:34:33

# %%
actor.first_name.value_counts()
# Out:
# PENELOPE    4
# JULIA       4
# KENNETH     4
# GENE        3
# GROUCHO     3
#            ..
# HENRY       1
# DUSTIN      1
# JUDE        1
# CARMEN      1
# THORA       1
# Name: first_name, Length: 128, dtype: int64

# %%
actor.last_name.value_counts()
# Out:
# KILMER     5
# TEMPLE     4
# NOLTE      4
# GUINESS    3
# ALLEN      3
#           ..
# JOLIE      1
# DAMON      1
# CRUZ       1
# SINATRA    1
# WALKEN     1
# Name: last_name, Length: 121, dtype: int64

# %%
category.head(20)
# Out:
#     category_id         name          last_update
# 0             1       Action  2006-02-15 04:46:27
# 1             2    Animation  2006-02-15 04:46:27
# 2             3     Children  2006-02-15 04:46:27
# 3             4     Classics  2006-02-15 04:46:27
# 4             5       Comedy  2006-02-15 04:46:27
# 5             6  Documentary  2006-02-15 04:46:27
# 6             7        Drama  2006-02-15 04:46:27
# 7             8       Family  2006-02-15 04:46:27
# 8             9      Foreign  2006-02-15 04:46:27
# 9            10        Games  2006-02-15 04:46:27
# 10           11       Horror  2006-02-15 04:46:27
# 11           12        Music  2006-02-15 04:46:27
# 12           13          New  2006-02-15 04:46:27
# 13           14       Sci-Fi  2006-02-15 04:46:27
# 14           15       Sports  2006-02-15 04:46:27
# 15           16       Travel  2006-02-15 04:46:27

# %%
category.shape
# Out:
# (16, 3)

# %%
category.tail(20)
# Out:
#     category_id         name          last_update
# 0             1       Action  2006-02-15 04:46:27
# 1             2    Animation  2006-02-15 04:46:27
# 2             3     Children  2006-02-15 04:46:27
# 3             4     Classics  2006-02-15 04:46:27
# 4             5       Comedy  2006-02-15 04:46:27
# 5             6  Documentary  2006-02-15 04:46:27
# 6             7        Drama  2006-02-15 04:46:27
# 7             8       Family  2006-02-15 04:46:27
# 8             9      Foreign  2006-02-15 04:46:27
# 9            10        Games  2006-02-15 04:46:27
# 10           11       Horror  2006-02-15 04:46:27
# 11           12        Music  2006-02-15 04:46:27
# 12           13          New  2006-02-15 04:46:27
# 13           14       Sci-Fi  2006-02-15 04:46:27
# 14           15       Sports  2006-02-15 04:46:27
# 15           16       Travel  2006-02-15 04:46:27

# %%
category.shape
# Out:
# (16, 3)

# %%
category.columns
# Out:
# Index(['category_id', 'name', 'last_update'], dtype='object')

# %%
category.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category_id  16 non-null     int64
#  1   name         16 non-null     object
#  2   last_update  16 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 2.4 KB

# %%
category.describe(include='all').T
# Out:
#             count unique                  top freq mean       std  min   25%  \
# category_id  16.0    NaN                  NaN  NaN  8.5  4.760952  1.0  4.75
# name           16     16               Action    1  NaN       NaN  NaN   NaN
# last_update    16      1  2006-02-15 04:46:27   16  NaN       NaN  NaN   NaN
#
#              50%    75%   max
# category_id  8.5  12.25  16.0
# name         NaN    NaN   NaN
# last_update  NaN    NaN   NaN

# %%
film.head(20)
# Out:
#     film_id                title  \
# 0         1     ACADEMY DINOSAUR
# 1         2       ACE GOLDFINGER
# 2         3     ADAPTATION HOLES
# 3         4     AFFAIR PREJUDICE
# 4         5          AFRICAN EGG
# 5         6         AGENT TRUMAN
# 6         7      AIRPLANE SIERRA
# 7         8      AIRPORT POLLOCK
# 8         9        ALABAMA DEVIL
# 9        10     ALADDIN CALENDAR
# 10       11      ALAMO VIDEOTAPE
# 11       12       ALASKA PHANTOM
# 12       13          ALI FOREVER
# 13       14       ALICE FANTASIA
# 14       15         ALIEN CENTER
# 15       16      ALLEY EVOLUTION
# 16       17           ALONE TRIP
# 17       18        ALTER VICTORY
# 18       19         AMADEUS HOLY
# 19       20  AMELIE HELLFIGHTERS
#
#                                           description  release_year  \
# 0   A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1   A Astounding Epistle of a Database Administrat...          2006
# ...

# %%
film.shape
# Out:
# (1000, 13)

# %%
film.tail(20)
# Out:
#      film_id                 title  \
# 980      981         WOLVES DESIRE
# 981      982          WOMEN DORADO
# 982      983             WON DARES
# 983      984        WONDERFUL DROP
# 984      985  WONDERLAND CHRISTMAS
# 985      986             WONKA SEA
# 986      987          WORDS HUNTER
# 987      988         WORKER TARZAN
# 988      989   WORKING MICROCOSMOS
# 989      990    WORLD LEATHERNECKS
# 990      991          WORST BANGER
# 991      992            WRATH MILE
# 992      993        WRONG BEHAVIOR
# 993      994         WYOMING STORM
# 994      995           YENTL IDAHO
# 995      996        YOUNG LANGUAGE
# 996      997            YOUTH KICK
# 997      998          ZHIVAGO CORE
# 998      999     ZOOLANDER FICTION
# 999     1000             ZORRO ARK
#
#                                            description  release_year  \
# 980  A Fast-Paced Drama of a Squirrel And a Robot w...          2006
# 981  A Insightful Documentary of a Waitress And a B...          2006
# ...

# %%
film.describe(include='all').T
# Out:
#                        count unique  \
# film_id               1000.0    NaN
# title                   1000   1000
# description             1000   1000
# release_year          1000.0    NaN
# language_id           1000.0    NaN
# original_language_id     0.0    NaN
# rental_duration       1000.0    NaN
# rental_rate           1000.0    NaN
# length                1000.0    NaN
# replacement_cost      1000.0    NaN
# rating                  1000      5
# special_features        1000     15
# last_update             1000      1
#
#                                                                     top  freq  \
# film_id                                                             NaN   NaN
# title                                                  ACADEMY DINOSAUR     1
# description           A Epic Drama of a Feminist And a Mad Scientist...     1
# release_year                                                        NaN   NaN
# ...

# %%
inventory.head(20)
# Out:
#     inventory_id  film_id  store_id          last_update
# 0              1        1         1  2006-02-15 05:09:17
# 1              2        1         1  2006-02-15 05:09:17
# 2              3        1         1  2006-02-15 05:09:17
# 3              4        1         1  2006-02-15 05:09:17
# 4              5        1         2  2006-02-15 05:09:17
# 5              6        1         2  2006-02-15 05:09:17
# 6              7        1         2  2006-02-15 05:09:17
# 7              8        1         2  2006-02-15 05:09:17
# 8              9        2         2  2006-02-15 05:09:17
# 9             10        2         2  2006-02-15 05:09:17
# 10            11        2         2  2006-02-15 05:09:17
# 11            12        3         2  2006-02-15 05:09:17
# 12            13        3         2  2006-02-15 05:09:17
# 13            14        3         2  2006-02-15 05:09:17
# 14            15        3         2  2006-02-15 05:09:17
# ...

# %%
inventory.shape
# Out:
# (1000, 4)

# %%
inventory.tail(20)
# Out:
#      inventory_id  film_id  store_id          last_update
# 980           981      219         1  2006-02-15 05:09:17
# 981           982      219         1  2006-02-15 05:09:17
# 982           983      219         1  2006-02-15 05:09:17
# 983           984      219         1  2006-02-15 05:09:17
# 984           985      220         1  2006-02-15 05:09:17
# 985           986      220         1  2006-02-15 05:09:17
# 986           987      220         1  2006-02-15 05:09:17
# 987           988      220         1  2006-02-15 05:09:17
# 988           989      220         2  2006-02-15 05:09:17
# 989           990      220         2  2006-02-15 05:09:17
# 990           991      220         2  2006-02-15 05:09:17
# 991           992      220         2  2006-02-15 05:09:17
# 992           993      222         1  2006-02-15 05:09:17
# 993           994      222         1  2006-02-15 05:09:17
# 994           995      222         2  2006-02-15 05:09:17
# ...

# %%
inventory.info
# Out:
# <bound method DataFrame.info of      inventory_id  film_id  store_id          last_update
# 0               1        1         1  2006-02-15 05:09:17
# 1               2        1         1  2006-02-15 05:09:17
# 2               3        1         1  2006-02-15 05:09:17
# 3               4        1         1  2006-02-15 05:09:17
# 4               5        1         2  2006-02-15 05:09:17
# ..            ...      ...       ...                  ...
# 995           996      222         2  2006-02-15 05:09:17
# 996           997      222         2  2006-02-15 05:09:17
# 997           998      222         2  2006-02-15 05:09:17
# 998           999      223         2  2006-02-15 05:09:17
# 999          1000      223         2  2006-02-15 05:09:17
#
# [1000 rows x 4 columns]>

# %%
inventory.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  1000 non-null   int64
#  1   film_id       1000 non-null   int64
#  2   store_id      1000 non-null   int64
#  3   last_update   1000 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 97.8 KB

# %%
inventory.film_id.unique
# Out:
# <bound method Series.unique of 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#       ...
# 995    222
# 996    222
# 997    222
# 998    223
# 999    223
# Name: film_id, Length: 1000, dtype: int64>

# %%
inventory.describe(include='all').T
# Out:
#                count unique                  top  freq     mean         std  \
# inventory_id  1000.0    NaN                  NaN   NaN    500.5  288.819436
# film_id       1000.0    NaN                  NaN   NaN  109.866   63.862042
# store_id      1000.0    NaN                  NaN   NaN    1.497    0.500241
# last_update     1000      1  2006-02-15 05:09:17  1000      NaN         NaN
#
#               min     25%    50%     75%     max
# inventory_id  1.0  250.75  500.5  750.25  1000.0
# film_id       1.0    56.0  111.5   164.0   223.0
# store_id      1.0     1.0    1.0     2.0     2.0
# last_update   NaN     NaN    NaN     NaN     NaN

# %%
language.head(10)
# Out:
#    language_id      name          last_update
# 0            1   English  2006-02-15 05:02:19
# 1            2   Italian  2006-02-15 05:02:19
# 2            3  Japanese  2006-02-15 05:02:19
# 3            4  Mandarin  2006-02-15 05:02:19
# 4            5    French  2006-02-15 05:02:19
# 5            6    German  2006-02-15 05:02:19

# %%
language.tail(10)
# Out:
#    language_id      name          last_update
# 0            1   English  2006-02-15 05:02:19
# 1            2   Italian  2006-02-15 05:02:19
# 2            3  Japanese  2006-02-15 05:02:19
# 3            4  Mandarin  2006-02-15 05:02:19
# 4            5    French  2006-02-15 05:02:19
# 5            6    German  2006-02-15 05:02:19

# %%
language.describe(include='all').T
# Out:
#             count unique                  top freq mean       std  min   25%  \
# language_id   6.0    NaN                  NaN  NaN  3.5  1.870829  1.0  2.25
# name            6      6              English    1  NaN       NaN  NaN   NaN
# last_update     6      1  2006-02-15 05:02:19    6  NaN       NaN  NaN   NaN
#
#              50%   75%  max
# language_id  3.5  4.75  6.0
# name         NaN   NaN  NaN
# last_update  NaN   NaN  NaN

# %%
language.info
# Out:
# <bound method DataFrame.info of    language_id      name          last_update
# 0            1   English  2006-02-15 05:02:19
# 1            2   Italian  2006-02-15 05:02:19
# 2            3  Japanese  2006-02-15 05:02:19
# 3            4  Mandarin  2006-02-15 05:02:19
# 4            5    French  2006-02-15 05:02:19
# 5            6    German  2006-02-15 05:02:19>

# %%
language.name.unique()
# Out:
# array(['English', 'Italian', 'Japanese', 'Mandarin', 'French', 'German'],
#       dtype=object)

# %%
old_HDD.head(20)
# Out:
#    first_name last_name                  title  release_year  category_id
# 0    PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1    PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2    PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3    PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4    PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# 5    PENELOPE   GUINESS     COLOR PHILADELPHIA          2006            4
# 6    PENELOPE   GUINESS        ELEPHANT TROJAN          2006           11
# 7    PENELOPE   GUINESS    GLEAMING JAWBREAKER          2006           15
# 8    PENELOPE   GUINESS         HUMAN GRAFFITI          2006           10
# 9    PENELOPE   GUINESS         KING EVOLUTION          2006            8
# 10   PENELOPE   GUINESS             LADY STAGE          2006           11
# 11   PENELOPE   GUINESS        LANGUAGE COWBOY          2006            3
# ...

# %%
old_HDD.shape
# Out:
# (1000, 5)

# %%
old_HDD.tail(20)
# Out:
#     first_name last_name               title  release_year  category_id
# 980        TOM  MCKELLEN         INDIAN LOVE          2006            8
# 981        TOM  MCKELLEN       KISSING DOLLS          2006            1
# 982        TOM  MCKELLEN         LEGEND JEDI          2006           12
# 983        TOM  MCKELLEN      MAGIC MALLRATS          2006            3
# 984        TOM  MCKELLEN   MISSION ZOOLANDER          2006            2
# 985        TOM  MCKELLEN   NECKLACE OUTBREAK          2006            7
# 986        TOM  MCKELLEN   NEIGHBORS CHARADE          2006           15
# 987        TOM  MCKELLEN        PURPLE MOVIE          2006            9
# 988        TOM  MCKELLEN       SHRUNK DIVINE          2006            1
# 989        TOM  MCKELLEN      SPICE SORORITY          2006            7
# 990        TOM  MCKELLEN   STALLION SUNDANCE          2006           14
# 991        TOM  MCKELLEN  STRANGER STRANGERS          2006            3
# ...

# %%
old_HDD.describe(include='all').T
# Out:
#                count unique                top freq    mean       std     min  \
# first_name      1000     38             SANDRA   56     NaN       NaN     NaN
# last_name       1000     37            OLIVIER   53     NaN       NaN     NaN
# title           1000    614  BOONDOCK BALLROOM    6     NaN       NaN     NaN
# release_year  1000.0    NaN                NaN  NaN  2006.0       0.0  2006.0
# category_id   1000.0    NaN                NaN  NaN   8.355  4.726872     1.0
#
#                  25%     50%     75%     max
# first_name       NaN     NaN     NaN     NaN
# last_name        NaN     NaN     NaN     NaN
# title            NaN     NaN     NaN     NaN
# release_year  2006.0  2006.0  2006.0  2006.0
# category_id      4.0     8.0    13.0    16.0

# %%
old_HDD.info
# Out:
# <bound method DataFrame.info of     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]>

# %%
old_HDD.last_name.unique()
# Out:
# array(['GUINESS', 'WAHLBERG', 'CHASE', 'DAVIS', 'LOLLOBRIGIDA',
#        'NICHOLSON', 'MOSTEL', 'JOHANSSON', 'SWANK', 'GABLE', 'CAGE',
#        'BERRY', 'WOOD', 'BERGEN', 'OLIVIER', 'COSTNER', 'VOIGHT', 'TORN',
#        'FAWCETT', 'TRACY', 'PALTROW', 'MARX', 'KILMER', 'STREEP', 'BLOOM',
#        'CRAWFORD', 'MCQUEEN', 'HOFFMAN', 'WAYNE', 'PECK', 'SOBIESKI',
#        'HACKMAN', 'DEAN', 'DUKAKIS', 'BOLGER', 'MCKELLEN', 'BRODY'],
#       dtype=object)

# %%
rental.head(20)
# Out:
#     rental_id          rental_date  inventory_id  customer_id  \
# 0           1  2005-05-24 22:53:30           367          130
# 1           2  2005-05-24 22:54:33          1525          459
# 2           3  2005-05-24 23:03:39          1711          408
# 3           4  2005-05-24 23:04:41          2452          333
# 4           5  2005-05-24 23:05:21          2079          222
# 5           6  2005-05-24 23:08:07          2792          549
# 6           7  2005-05-24 23:11:53          3995          269
# 7           8  2005-05-24 23:31:46          2346          239
# 8           9  2005-05-25 00:00:40          2580          126
# 9          10  2005-05-25 00:02:21          1824          399
# 10         11  2005-05-25 00:09:02          4443          142
# 11         12  2005-05-25 00:19:27          1584          261
# 12         13  2005-05-25 00:22:55          2294          334
# 13         14  2005-05-25 00:31:15          2701          446
# ...

# %%
rental.tail(20)
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 980        982  2005-05-30 22:15:24          3560          524
# 981        983  2005-05-30 22:15:51            63          115
# 982        984  2005-05-30 22:17:17          2305          262
# 983        985  2005-05-30 22:18:35          1573          564
# 984        986  2005-05-30 22:22:52          4045          253
# 985        987  2005-05-30 22:59:12           390           11
# 986        988  2005-05-30 23:08:03          1364           12
# 987        989  2005-05-30 23:11:51          4388           83
# 988        990  2005-05-30 23:25:14          4171          311
# 989        991  2005-05-30 23:29:22          2863          593
# 990        992  2005-05-30 23:47:56          3572          123
# 991        993  2005-05-30 23:54:19          2080          513
# 992        994  2005-05-30 23:55:36          2798          472
# 993        995  2005-05-31 00:06:02            17          150
# ...

# %%
rental.describe(include='all').T
# Out:
#                count unique                  top  freq      mean          std  \
# rental_id     1000.0    NaN                  NaN   NaN    501.18    289.19665
# rental_date     1000    999  2005-05-30 14:47:31     2       NaN          NaN
# inventory_id  1000.0    NaN                  NaN   NaN  2258.179  1314.667454
# customer_id   1000.0    NaN                  NaN   NaN   296.408   172.509319
# return_date     1000    997  2005-06-05 15:16:54     2       NaN          NaN
# staff_id      1000.0    NaN                  NaN   NaN     1.521     0.499809
# last_update     1000      1  2006-02-15 21:30:53  1000       NaN          NaN
#
#               min     25%     50%      75%     max
# rental_id     1.0  250.75   501.5   751.25  1001.0
# rental_date   NaN     NaN     NaN      NaN     NaN
# inventory_id  2.0  1157.5  2244.5  3371.75  4581.0
# customer_id   1.0   150.0   296.0   445.25   597.0
# return_date   NaN     NaN     NaN      NaN     NaN
# ...

# %%
rental.info
# Out:
# <bound method DataFrame.info of      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
# Out:
# Series([], dtype: int64)
